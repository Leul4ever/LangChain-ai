# %% [markdown]
# Data Ingestion-Documentaion
# https://python.langchain.com/v0.2/docs/integrations/document_loaders/

# %%
##  Text Loader 
from langchain_community.document_loaders import TextLoader
